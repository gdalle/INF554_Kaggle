# %%
# External imports
import pandas as pd
import numpy as np

# %%
# External imports 2
from sklearn import linear_model, svm, ensemble
from sklearn import dummy
from sklearn.model_selection import cross_val_score
from sklearn.metrics import log_loss, make_scorer

# %%
# Internal imports
import importlib
import extraction as ex
import features as feat
ex = importlib.reload(ex)
feat = importlib.reload(feat)

# %%
# All dataframes except user logs
train = ex.read_train()
test = ex.read_test()
members = ex.read_members()
transactions = ex.read_transactions(train, test, max_lines=10**8)
# Out:
# READING TRAIN
#
#
# Memory usage (MB) : 8.33381652832
# Index       7.407837
# is_churn    0.925980
# dtype: float64
#
#
# READING TEST
#
#
# Memory usage (MB) : 6.92345428467
# Index    6.923454
# dtype: float64
#
#
# READING MEMBERS
#
#
# Memory usage (MB) : 135.57332325
# Index                     51.646980
# city                       6.455873
# bd                        12.911745
# gender                     6.455873
# registered_via             6.455873
# registration_init_time    51.646980
# dtype: float64
#
#
# READING TRANSACTIONS
#
# Chunk 0 of table 1 read
# Chunk 1 of table 1 read
# Chunk 2 of table 1 read
# Chunk 3 of table 1 read
# Chunk 4 of table 1 read
# Chunk 5 of table 1 read
# Chunk 6 of table 1 read
# Chunk 7 of table 1 read
# Chunk 8 of table 1 read
# Chunk 9 of table 1 read
# Chunk 10 of table 1 read
# Chunk 11 of table 1 read
# Chunk 12 of table 1 read
# Chunk 13 of table 1 read
# Chunk 14 of table 1 read
# Chunk 15 of table 1 read
# Chunk 16 of table 1 read
# Chunk 17 of table 1 read
# Chunk 18 of table 1 read
# Chunk 19 of table 1 read
# Chunk 20 of table 1 read
# Chunk 21 of table 1 read
# Chunk 22 of table 1 read
# Chunk 23 of table 1 read
# Chunk 24 of table 1 read
# Chunk 25 of table 1 read
# Chunk 26 of table 1 read
# Chunk 27 of table 1 read
# Chunk 28 of table 1 read
# Chunk 29 of table 1 read
# Chunk 30 of table 1 read
# Chunk 31 of table 1 read
# Chunk 32 of table 1 read
# Chunk 33 of table 1 read
# Chunk 34 of table 1 read
# Chunk 35 of table 1 read
# Chunk 36 of table 1 read
# Chunk 37 of table 1 read
# Chunk 38 of table 1 read
# Chunk 39 of table 1 read
# Chunk 40 of table 1 read
# Chunk 41 of table 1 read
# Chunk 42 of table 1 read
# Chunk 43 of table 1 read
# Chunk 44 of table 1 read
# Chunk 45 of table 1 read
# Chunk 46 of table 1 read
# Chunk 47 of table 1 read
# Chunk 48 of table 1 read
# Chunk 49 of table 1 read
# Chunk 50 of table 1 read
# Chunk 51 of table 1 read
# Chunk 52 of table 1 read
# Chunk 53 of table 1 read
# Chunk 54 of table 1 read
# Chunk 55 of table 1 read
# Chunk 56 of table 1 read
# Chunk 57 of table 1 read
# Chunk 58 of table 1 read
# Chunk 59 of table 1 read
# Chunk 60 of table 1 read
# Chunk 61 of table 1 read
# Chunk 62 of table 1 read
# Chunk 63 of table 1 read
# Chunk 64 of table 1 read
# Chunk 65 of table 1 read
# Chunk 66 of table 1 read
# Chunk 67 of table 1 read
# Chunk 68 of table 1 read
# Chunk 69 of table 1 read
# Chunk 70 of table 1 read
# Chunk 71 of table 1 read
# Chunk 72 of table 1 read
# Chunk 73 of table 1 read
# Chunk 74 of table 1 read
# Chunk 75 of table 1 read
# Chunk 76 of table 1 read
# Chunk 77 of table 1 read
# Chunk 78 of table 1 read
# Chunk 79 of table 1 read
# Chunk 80 of table 1 read
# Chunk 81 of table 1 read
# Chunk 82 of table 1 read
# Chunk 83 of table 1 read
# Chunk 84 of table 1 read
# Chunk 85 of table 1 read
# Chunk 86 of table 1 read
# Chunk 87 of table 1 read
# Chunk 88 of table 1 read
# Chunk 89 of table 1 read
# Chunk 90 of table 1 read
# Chunk 91 of table 1 read
# Chunk 92 of table 1 read
# Chunk 93 of table 1 read
# Chunk 94 of table 1 read
# Chunk 95 of table 1 read
# Chunk 96 of table 1 read
# Chunk 97 of table 1 read
# Chunk 98 of table 1 read
# Chunk 99 of table 1 read
# Chunk 100 of table 1 read
# Chunk 101 of table 1 read
# Chunk 102 of table 1 read
# Chunk 103 of table 1 read
# Chunk 104 of table 1 read
# Chunk 105 of table 1 read
# Chunk 106 of table 1 read
# Chunk 107 of table 1 read
# Chunk 108 of table 1 read
# Chunk 109 of table 1 read
# Chunk 110 of table 1 read
# Chunk 111 of table 1 read
# Chunk 112 of table 1 read
# Chunk 113 of table 1 read
# Chunk 114 of table 1 read
# Chunk 115 of table 1 read
# Chunk 116 of table 1 read
# Chunk 117 of table 1 read
# Chunk 118 of table 1 read
# Chunk 119 of table 1 read
# Chunk 120 of table 1 read
# Chunk 121 of table 1 read
# Chunk 122 of table 1 read
# Chunk 123 of table 1 read
# Chunk 124 of table 1 read
# Chunk 125 of table 1 read
# Chunk 126 of table 1 read
# Chunk 127 of table 1 read
# Chunk 128 of table 1 read
# Chunk 129 of table 1 read
# Chunk 130 of table 1 read
# Chunk 131 of table 1 read
# Chunk 132 of table 1 read
# Chunk 133 of table 1 read
# Chunk 134 of table 1 read
# Chunk 135 of table 1 read
# Chunk 136 of table 1 read
# Chunk 137 of table 1 read
# Chunk 138 of table 1 read
# Chunk 139 of table 1 read
# Chunk 140 of table 1 read
# Chunk 141 of table 1 read
# Chunk 142 of table 1 read
# Chunk 143 of table 1 read
# Chunk 144 of table 1 read
# Chunk 145 of table 1 read
# Chunk 146 of table 1 read
# Chunk 147 of table 1 read
# Chunk 148 of table 1 read
# Chunk 149 of table 1 read
# Chunk 150 of table 1 read
# Chunk 151 of table 1 read
# Chunk 152 of table 1 read
# Chunk 153 of table 1 read
# Chunk 154 of table 1 read
# Chunk 155 of table 1 read
# Chunk 156 of table 1 read
# Chunk 157 of table 1 read
# Chunk 158 of table 1 read
# Chunk 159 of table 1 read
# Chunk 160 of table 1 read
# Chunk 161 of table 1 read
# Chunk 162 of table 1 read
# Chunk 163 of table 1 read
# Chunk 164 of table 1 read
# Chunk 165 of table 1 read
# Chunk 166 of table 1 read
# Chunk 167 of table 1 read
# Chunk 168 of table 1 read
# Chunk 169 of table 1 read
# Chunk 170 of table 1 read
# Chunk 171 of table 1 read
# Chunk 172 of table 1 read
# Chunk 173 of table 1 read
# Chunk 174 of table 1 read
# Chunk 175 of table 1 read
# Chunk 176 of table 1 read
# Chunk 177 of table 1 read
# Chunk 178 of table 1 read
# Chunk 179 of table 1 read
# Chunk 180 of table 1 read
# Chunk 181 of table 1 read
# Chunk 182 of table 1 read
# Chunk 183 of table 1 read
# Chunk 184 of table 1 read
# Chunk 185 of table 1 read
# Chunk 186 of table 1 read
# Chunk 187 of table 1 read
# Chunk 188 of table 1 read
# Chunk 189 of table 1 read
# Chunk 190 of table 1 read
# Chunk 191 of table 1 read
# Chunk 192 of table 1 read
# Chunk 193 of table 1 read
# Chunk 194 of table 1 read
# Chunk 195 of table 1 read
# Chunk 196 of table 1 read
# Chunk 197 of table 1 read
# Chunk 198 of table 1 read
# Chunk 199 of table 1 read
# Chunk 200 of table 1 read
# Chunk 201 of table 1 read
# Chunk 202 of table 1 read
# Chunk 203 of table 1 read
# Chunk 204 of table 1 read
# Chunk 205 of table 1 read
# Chunk 206 of table 1 read
# Chunk 207 of table 1 read
# Chunk 208 of table 1 read
# Chunk 209 of table 1 read
# Chunk 210 of table 1 read
# Chunk 211 of table 1 read
# Chunk 212 of table 1 read
# Chunk 213 of table 1 read
# Chunk 214 of table 1 read
# Chunk 215 of table 1 read
# Chunk 0 of table 2 read
# Chunk 1 of table 2 read
# Chunk 2 of table 2 read
# Chunk 3 of table 2 read
# Chunk 4 of table 2 read
# Chunk 5 of table 2 read
# Chunk 6 of table 2 read
# Chunk 7 of table 2 read
# Chunk 8 of table 2 read
# Chunk 9 of table 2 read
# Chunk 10 of table 2 read
# Chunk 11 of table 2 read
# Chunk 12 of table 2 read
# Chunk 13 of table 2 read
# Chunk 14 of table 2 read
#
# Memory usage (MB) : 669.92029953
# Index                     130.716156
# msno                      130.716156
# payment_method_id          16.339520
# payment_plan_days          32.679039
# plan_list_price            32.679039
# actual_amount_paid         32.679039
# is_auto_renew              16.339520
# transaction_date          130.716156
# membership_expire_date    130.716156
# is_cancel                  16.339520
# dtype: float64

# %%
# Read user logs
user_logs = ex.read_user_logs(train, test, max_lines=10**7, chunksize=10**6)
# Out:
# READING USER LOGS
#
# Chunk 0 of table 1 read
# Chunk 1 of table 1 read
# Chunk 2 of table 1 read
# Chunk 3 of table 1 read
# Chunk 4 of table 1 read
# Chunk 5 of table 1 read
# Chunk 6 of table 1 read
# Chunk 7 of table 1 read
# Chunk 8 of table 1 read
# Chunk 9 of table 1 read
# Chunk 10 of table 1 read
# Chunk 11 of table 1 read
# Chunk 12 of table 1 read
# Chunk 13 of table 1 read
# Chunk 14 of table 1 read
# Chunk 15 of table 1 read
# Chunk 16 of table 1 read
# Chunk 17 of table 1 read
# Chunk 18 of table 1 read
# Chunk 19 of table 1 read
# Chunk 20 of table 1 read
# Chunk 21 of table 1 read
# Chunk 22 of table 1 read
# Chunk 23 of table 1 read
# Chunk 24 of table 1 read
# Chunk 25 of table 1 read
# Chunk 26 of table 1 read
# Chunk 27 of table 1 read
# Chunk 28 of table 1 read
# Chunk 29 of table 1 read
# Chunk 30 of table 1 read
# Chunk 31 of table 1 read
# Chunk 32 of table 1 read
# Chunk 33 of table 1 read
# Chunk 34 of table 1 read
# Chunk 35 of table 1 read
# Chunk 36 of table 1 read
# Chunk 37 of table 1 read
# Chunk 38 of table 1 read
# Chunk 39 of table 1 read
# Chunk 40 of table 1 read
# Chunk 41 of table 1 read
# Chunk 42 of table 1 read
# Chunk 43 of table 1 read
# Chunk 44 of table 1 read
# Chunk 45 of table 1 read
# Chunk 46 of table 1 read
# Chunk 47 of table 1 read
# Chunk 48 of table 1 read
# Chunk 49 of table 1 read
# Chunk 50 of table 1 read
# Chunk 51 of table 1 read
# Chunk 52 of table 1 read
# Chunk 53 of table 1 read
# Chunk 54 of table 1 read
# Chunk 55 of table 1 read
# Chunk 56 of table 1 read
# Chunk 57 of table 1 read
# Chunk 58 of table 1 read
# Chunk 59 of table 1 read
# Chunk 60 of table 1 read
# Chunk 61 of table 1 read
# Chunk 62 of table 1 read
# Chunk 63 of table 1 read
# Chunk 64 of table 1 read
# Chunk 65 of table 1 read
# Chunk 66 of table 1 read
# Chunk 67 of table 1 read
# Chunk 68 of table 1 read
# Chunk 69 of table 1 read
# Chunk 70 of table 1 read
# Chunk 71 of table 1 read
# Chunk 72 of table 1 read
# Chunk 73 of table 1 read
# Chunk 74 of table 1 read
# Chunk 75 of table 1 read
# Chunk 76 of table 1 read
# Chunk 77 of table 1 read
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-e6efd608975f> in <module>()
#       1 # Read user logs
# ----> 2 user_logs = ex.read_user_logs(train, test, max_lines=10**7, chunksize=10**6)
#
# ~/INF554_Kaggle/proj2/extraction.py in read_user_logs(train, test, max_lines, split_dates, chunksize)
#     253         iterator=True,
#     254         header=0,
# --> 255         dtype=dtype_cols_user_logs
#     256     ):
#     257         append_condition = df['msno'].isin(useful_msno)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __next__(self)
#    1036     def __next__(self):
#    1037         try:
# -> 1038             return self.get_chunk()
#    1039         except StopIteration:
#    1040             self.close()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1100                 raise StopIteration
#    1101             size = min(size, self.nrows - self._currow)
# -> 1102         return self.read(nrows=size)
#    1103
#    1104
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1063                 raise ValueError('skipfooter not supported for iteration')
#    1064
# -> 1065         ret = self._engine.read(nrows)
#    1066
#    1067         if self.options.get('as_recarray'):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1826     def read(self, nrows=None):
#    1827         try:
# -> 1828             data = self._reader.read(nrows)
#    1829         except StopIteration:
#    1830             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_integer_dtype(arr_or_dtype)
#     775
#     776
# --> 777 def is_integer_dtype(arr_or_dtype):
#     778     """
#     779     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:

# %%
# Get useful users, appearing in the tables we are interested in
train_useful = feat.get_useful_users(train, members=members, transactions=transactions, user_logs=None)
test_useful = feat.get_useful_users(test, members=members, transactions=transactions, user_logs=None)
# Out:
# Getting useful users
# - Members
# - Transactions
# Getting useful users
# - Members
# - Transactions

# %%
# Exploring members
modified_members = members.copy().drop("registration_init_time", axis=1)

# %%
# City (categories)
modified_members = feat.categorize(modified_members, "city")
# Bd (categories)
modified_members = feat.categorize(modified_members, "bd")
# Gender (categories)
modified_members = feat.categorize(modified_members, "gender")
# Registered via (categories)
modified_members = feat.categorize(modified_members, "registered_via")

# %%
# Registration init time
registration_init = pd.DataFrame(
    data = feat.count_days(members["registration_init_time"]),
    index = modified_members.index,
    columns=["registration_init_time"]
)

# %%
# Exploring transactions
grouped_trans = transactions.groupby("msno")

# %%
# Latest transactions and planned expiration
latest_trans = grouped_trans.max()
latest_trans = latest_trans.loc[:, ["transaction_date", "membership_expire_date"]]
latest_trans = latest_trans.apply(feat.count_days)
latest_trans.columns = ["latest_transaction_date", "planned_membership_expire_date"]

# %%
# Transaction duration
trans_dates = transactions.loc[:, ["msno", "membership_expire_date", "transaction_date"]]
trans_dur = trans_dates["membership_expire_date"]-trans_dates["transaction_date"]
trans_dur = feat.count_days(trans_dur)
trans_dates = trans_dates.assign(mean_transaction_duration=trans_dur)
mean_trans_dates = trans_dates.groupby("msno").mean()
mean_trans_dur = mean_trans_dates.loc[:, ["mean_transaction_duration"]]

# %%
# Auto-renew and cancel
trans_caracs = grouped_trans.mean()
trans_caracs = trans_caracs.loc[:, ["is_auto_renew", "is_cancel"]]
trans_caracs.columns = ["auto_renew_freq", "cancel_freq"]

# %%
# Exploring user logs
grouped_logs = user_logs.groupby("msno")

# %%
# Mean logs
mean_logs = grouped_logs.mean()
cols = mean_logs.columns
mean_logs.columns = ["mean_" + col for col in cols]

# %%
# Latest listening session
latest_session = grouped_logs.max().loc[:, ["date"]]
latest_session = latest_session.apply(feat.count_days)
latest_session.columns = ["latest_listening_session"]

# %%
# Number of listening sessions
logs_count = grouped_logs.count().loc[:, ["date"]]
logs_count.columns = ["number_listening_sessions"]

# %%
# Merge all extracted data
members_data = [modified_members, registration_init]
transactions_data = [latest_trans, mean_trans_dur, trans_caracs]
# user_logs_data = [latest_session, logs_count, mean_logs]
user_logs_data = []

train_full = train_useful.copy()
test_full = test_useful.copy()

# Make a biiiiig dataframe
for df in user_logs_data + transactions_data + members_data:
    # Select only the interesting part of the index
    df_train = df.reindex(train_full.index)
    df_test = df.reindex(test_full.index)
    # Concatenate
    train_full = pd.concat([train_full, df_train], axis=1)
    test_full = pd.concat([test_full, df_test], axis=1)

# %%
# Normalize features
for c in test_full.columns:
    # If not binary:
    if train_full[c].max() > 1.001 or train_full[c].min() < -0.001:
        # Standardize in train, and in test with the scale parameters of train
        m = train_full[c].mean()
        s = train_full[c].std()
        train_full[c] = (train_full[c] - m) / s
        test_full[c] = (test_full[c] - m) / s

# %%
train_full.head()
# Out:
#                                               is_churn  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1
#
#                                               latest_transaction_date  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                -0.384389
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                -0.070034
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                 0.015699
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=               -10.929560
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                 0.072854
#
#                                               planned_membership_expire_date  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                       -0.496194
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                       -0.263737
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                        0.995403
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                        5.005281
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                        2.835685
#
#                                               mean_transaction_duration  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  -0.170748
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  -0.103830
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  -0.088343
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                   4.532287
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                   1.632687
#
#                                               auto_renew_freq  cancel_freq  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0.833333     0.166667
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0.000000     0.000000
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0.000000     0.000000
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0.965517     0.103448
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1.000000     0.093750
#
#                                               city_1  city_3  city_4  city_5  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=       0       0       0       1
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=       0       0       0       0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=       0       0       0       0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=       1       0       0       0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=       0       0       0       0
#
#                                                        ...            \
# msno                                                   ...
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=           ...
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=           ...
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=           ...
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=           ...
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=           ...
#
#                                               registered_via_9  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                 0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                 0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                 0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                 0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                 0
#
#                                               registered_via_10  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_11  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_13  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_14  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_16  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_17  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_18  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registered_via_19  \
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                  0
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                  0
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                  0
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                  0
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                  0
#
#                                               registration_init_time
# msno
# ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=                0.091752
# f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=                0.091752
# zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=                0.095397
# 8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=                0.107241
# K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=                0.121819
#
# [5 rows x 435 columns]

# %%
# Select features to use
features = [
    "latest_transaction_date",
    "registration_init_time",
    "mean_transaction_duration",
    "auto_renew_freq",
    "cancel_freq"
]
# registration_modes = [int(c[15:]) for c in train_full.columns if c[:14] == "registered_via"]
# features += ["registered_via_" + str(i) for i in registration_modes]

train_filtered = train_full.loc[:, features + ["is_churn"]]
test_filtered = test_full.loc[:, features]

# %%
# Here comes the machine learning

# Conversion into arrays for scikit-learn
x = np.array(train_filtered.drop("is_churn", axis=1))
y = np.array(train_filtered["is_churn"])
xt = np.array(test_filtered)

# Train a logistic regression
clf = linear_model.LogisticRegression()
# clf = linear_model.Ridge(alpha=0.)
clf.fit(x, y)

try:
    # Compute the probability of belonging to class 1 (and not 0)
    proba = True
    yt = clf.predict_proba(xt)[:, 1]
except AttributeError:
    # If impossible for this classifier, predict the value of the class
    # and restrict to the interval [0, 1]
    proba = False
    yt = clf.predict(xt)
    yt[yt < 0] = 0.
    yt[yt > 1] = 1.

# %%
# Perform cross-validation
log_loss_scorer = make_scorer(
    score_func=lambda y_true, y_pred: log_loss(
        y_true, y_pred, labels=[0, 1],
        eps=np.power(10., -15), normalize=True),
    greater_is_better=True,
    needs_proba=proba
)
scores = cross_val_score(
    estimator=clf,
    X=x,
    y=y,
    cv=5,
    scoring=log_loss_scorer
)
print("CV score (log-loss) : {}".format(scores.mean()))
# Out:
# CV score (log-loss) : 0.20387236196231484

# %%
# Zero prediction as baseline
percentage_churn = train_filtered["is_churn"].sum() / len(train_filtered)
test["is_churn"] = np.random.rand(len(test)) * percentage_churn
# For users on which we have more info, use it
test.loc[test_filtered.index, ["is_churn"]] = yt.reshape(-1, 1)

# Save as csv
submission = test.loc[:, ["is_churn"]]
submission.to_csv("data/submission.csv")
